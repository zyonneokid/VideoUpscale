# %% [markdown]
# # Video2X Browser App on Google Colab
#
# Run this notebook to start a browser UI for uploading a video and downloading a 4K result generated with Video2X.
#
# This notebook pulls the latest project files from GitHub into the Colab session automatically.

# %%
# !git clone https://github.com/zyonneokid/VideoUpscale.git

# %%
# %cd /content/VideoUpscale
# !apt-get update -qq
# !apt-get install -y -qq libvulkan1 mesa-vulkan-drivers
# %pip install -q -r requirements.txt

# %%
import app

demo = app.build_app()
demo.queue(default_concurrency_limit=1).launch(share=True, debug=True)
