# %% [markdown]
# # Video2X Browser App on Google Colab
#
# Run this notebook to start a browser UI for uploading a video and downloading a 4K result generated with Video2X.
#
# Before running it, make sure `app.py` is available in the same Colab working directory.

# %%
# %pip install -q gradio>=4.44.0

# %%
from pathlib import Path

if not Path('app.py').exists():
    raise FileNotFoundError('Upload app.py into the Colab session or open this notebook from the project folder.')

import app

demo = app.build_app()
demo.queue(default_concurrency_limit=1).launch(share=True, debug=True)
