# %% [markdown]
# <a href="https://colab.research.google.com/github/zyonneokid/VideoUpscale/blob/main/video2x_colab_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4K Video Upscaler on Google Colab
#
# This notebook starts a browser UI for uploading a video and downloading a 4K upscaled result.
#
# It pulls your app repo and the official Real-ESRGAN repo into the Colab session automatically.

# %%
# %cd /content
# !rm -rf /content/VideoUpscale /content/Real-ESRGAN
# !git clone https://github.com/zyonneokid/VideoUpscale.git /content/VideoUpscale
# !git clone https://github.com/xinntao/Real-ESRGAN.git /content/Real-ESRGAN
# Out:
# /content
# Cloning into '/content/VideoUpscale'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 44 (delta 24), reused 34 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 14.47 KiB | 14.47 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Cloning into '/content/Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Total 759 (delta 0), reused 0 (delta 0), pack-reused 759 (from 1)
# Receiving objects: 100% (759/759), 5.39 MiB | 33.22 MiB/s, done.
# Resolving deltas: 100% (408/408), done.

# %%
# %cd /content/Real-ESRGAN
# !apt-get update -qq
# !apt-get install -y -qq ffmpeg libgl1
# %pip install -q basicsr facexlib gfpgan ffmpeg-python
# %pip install -q -r requirements.txt
# %pip install -q -e .
# Out:
# /content/Real-ESRGAN
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#   Preparing metadata (setup.py) ... done

# %%
# %cd /content/VideoUpscale
# %pip install -q -r requirements.txt
# Out:
# /content/VideoUpscale

# %%
import os

os.environ['REAL_ESRGAN_DIR'] = '/content/Real-ESRGAN'

import app

demo = app.build_app()
demo.queue(default_concurrency_limit=1).launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://064ad9347f7582b93e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://064ad9347f7582b93e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
